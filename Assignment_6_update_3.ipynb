# %% [markdown]
# <a href="https://colab.research.google.com/github/subankarchy/hand-hygiene-/blob/main/Assignment_6_update_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Survey q2: Do you routinely use an alcohol-based rub for hand hygiene?

import matplotlib.pyplot as plt

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
yes_values = [13, 12, 10]
no_values = [1, 1, 0]

# Custom colors for Yes and No bars
yes_color = 'blue'
no_color = 'orange'

# Create figure and axis
fig, ax = plt.subplots()

# Plotting Yes bars with reduced width
ax.bar(roles, yes_values, color=yes_color, label='Yes', width=0.4)

# Plotting No bars on top of Yes bars with reduced width
ax.bar(roles, no_values, bottom=yes_values, color=no_color, label='No', width=0.4)

# Adding labels and title
ax.set_ylabel('Number of Individuals')
ax.set_xlabel('Roles')
ax.set_title('Hand Hygiene Responses by Role')
ax.legend()

# Display the plot
plt.show()

# %%
# Survey q2: Do you routinely use an alcohol-based rub for hand hygiene?


import matplotlib.pyplot as plt

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
yes_values = [92.8, 92.3, 90.9]
no_values = [7.14, 7.6, 0]

# Labels for the pie chart
labels = ['Yes', 'No']

# Colors for the pie chart
colors = ['#66B3FF', '#FF9999']

# Create a pie chart for each role
for i in range(len(roles)):
    plt.figure(figsize=(6, 6))
    plt.pie([yes_values[i], no_values[i]], labels=labels, autopct='%1.1f%%', startangle=140, colors=colors)
    plt.title(f'Hand Hygiene for {roles[i]}')
    plt.show()

# %%
# Survey q3: Have you received formal education/training in hand hygiene in the last three years?

import matplotlib.pyplot as plt

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
yes_values = [14, 11, 6]
no_values = [0, 2, 5]

# Custom colors for Yes and No bars
yes_color = 'blue'
no_color = 'orange'

# Create figure and axis
fig, ax = plt.subplots()

# Plotting Yes bars
ax.bar(roles, yes_values, color=yes_color, label='Yes', width=0.4)

# Plotting No bars on top of Yes bars
ax.bar(roles, no_values, bottom=yes_values, color=no_color, label='No', width=0.4)

# Adding labels and title
ax.set_ylabel('Number of Individuals')
ax.set_xlabel('Roles')
ax.set_title('Hand Hygiene Education/Training Responses by Role')
ax.legend()

# Display the plot
plt.show()

# %%
# Survey q3: Have you received formal education/training in hand hygiene in the last three years?

import matplotlib.pyplot as plt

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
yes_values = [100, 84.6, 0.54]
no_values = [0, 7.6, 0.45]

# Labels for the pie chart
labels = ['Yes', 'No']

# Colors for the pie chart
colors = ['#66B3FF', '#FF9999']

# Create a pie chart for each role
for i in range(len(roles)):
    plt.figure(figsize=(6, 6))
    plt.pie([yes_values[i], no_values[i]], labels=labels, autopct='%1.1f%%', startangle=140, colors=colors)
    plt.title(f'Education/Training in Hand Hygiene for {roles[i]}')
    plt.show()

# %%
# Survey q4: How much effort is required for you to perform good hand hygiene?

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
effort_levels = ['No effort', 'A little effort', 'Some effort', 'A large effort', 'A great deal of effort']
values = [
    [28.5, 35.7, 14.3, 21.4, 0],
    [15.3, 61.5, 15.3, 7.6, 0],
    [36.3, 45.4, 9, 0, 9]
]

# Create a NumPy array from the values list
data_array = np.array(values)

# Create a heatmap using Seaborn
plt.figure(figsize=(10, 6))  # Adjust figure size for better visualization
sns.heatmap(data_array, annot=True, cmap='YlGnBu', xticklabels=effort_levels, yticklabels=roles, fmt='.1f')

# Adding labels and title
plt.xlabel('Effort Level')
plt.ylabel('Roles')
plt.title('Effort Required for Good Hand Hygiene by Role (In Percentage)')

# Display the plot
plt.show()

# %%
# Survey q5: What is the effectiveness of hand hygiene in preventing health care associated infection?

import matplotlib.pyplot as plt
import numpy as np

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
effectiveness_levels = ['Not effective', 'Somewhat effective', 'Moderately effective', 'Highly effective', 'Very highly effective']
values = [
    [0, 0, 0, 57.2, 42.8],
    [0, 7.6, 7.6, 38.5, 46.2],
    [0, 0, 18.8, 54.1, 27.1]
]

# Convert values to NumPy array
data_array = np.array(values)

# Calculate the cumulative percentages for each role
cumulative_values = np.cumsum(data_array, axis=1)

# Create a grouped bar chart with percentage values on the bars
bar_width = 0.15
index = np.arange(len(roles))

plt.figure(figsize=(10, 6))  # Adjust figure size for better visualization

for i, effectiveness in enumerate(effectiveness_levels):
    plt.bar(index + i * bar_width, data_array[:, i], bar_width, label=effectiveness)
    for j, value in enumerate(data_array[:, i]):
        if value > 0:  # Check if the value is greater than 0
            plt.text(index[j] + i * bar_width, value + 1, f'{value:.1f}%', ha='center', va='bottom', fontsize=9, color='black')

# Adding labels and title
plt.xlabel('Roles')
plt.ylabel('Percentage')
plt.title('Effectiveness of Hand Hygiene in Preventing Healthcare-Associated Infection by Role (In Percentage)')
plt.xticks(index + bar_width * 2, roles)
plt.legend(title='Effectiveness Level')

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Survey q5: What is the effectiveness of hand hygiene in preventing health care associated infection?

import matplotlib.pyplot as plt

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
effectiveness_labels = ['Not effective', 'Somewhat effective', 'Moderately effective', 'Highly effective', 'Very highly effective']

# Effectiveness data for each role
data = [
    [0, 0, 0, 57.1, 42.8],
    [0, 7.6, 7.6, 38.4, 46.1],
    [0, 0, 18.9, 54.5, 27.3]
]

# Create pie charts for each role
plt.figure(figsize=(18, 6))  # Adjust the figure size

for i, role in enumerate(roles):
    plt.subplot(1, 3, i + 1)  # Create subplots for each role
    plt.title(f'Effectiveness of Hand Hygiene for {role}')

    # Filter out categories with 0% effectiveness
    non_zero_data = [data[i][j] for j in range(len(data[i])) if data[i][j] > 0]
    non_zero_labels = [effectiveness_labels[j] for j in range(len(data[i])) if data[i][j] > 0]

    plt.pie(non_zero_data, labels=non_zero_labels, autopct='%1.1f%%', startangle=90)
    plt.axis('equal')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
very_low_priority = [0, 0, 0]
low_priority = [0, 0, 27.1]
moderately_effective = [21.4, 23, 18.8]
highly_effective = [35.7, 46.2, 45.1]
very_highly_effective = [42.8, 30.8, 8.9]

x = np.arange(len(roles))
width = 0.15

# Increase the size of the figure even more
fig, ax = plt.subplots(figsize=(12, 8))

rects1 = ax.bar(x - 2 * width, very_low_priority, width, label='Very Low Priority')
rects2 = ax.bar(x - width, low_priority, width, label='Low Priority')
rects3 = ax.bar(x, moderately_effective, width, label='Moderate Priority')
rects4 = ax.bar(x + width, highly_effective, width, label='High Priority')
rects5 = ax.bar(x + 2 * width, very_highly_effective, width, label='Very High Priority')

ax.set_ylabel('Percentage')
ax.set_xlabel('Role')
ax.set_title('Priority of Hand Hygiene by Role (In Percentage)')
ax.set_xticks(x)
ax.set_xticklabels(roles)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        if height > 0:  # Check if the height is greater than 0
            ax.annotate('{}'.format(height),
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),  # Adjust the vertical offset to move the label above the bar
                        textcoords="offset points",
                        ha='center', va='bottom',
                        fontsize=12,  # Set the fontsize for the labels
                        color='black')  # Use black color for labels

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)

fig.tight_layout()

plt.show()

# %%
# Survey q6: In your opinion, among all patient safety issues, how much of a priority is hand hygiene at your institution?

import matplotlib.pyplot as plt

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
priority_labels = ['Very low priority', 'Low priority', 'Moderately effective', 'Highly effective', 'Very highli effective']

# Priority data for each role
data = [
    [0, 0, 21.4, 35.7, 42.8],
    [0, 0, 23, 46.1, 30.7],
    [0, 27.3, 18.9, 45.4, 9]
]

# Create pie charts for each role
plt.figure(figsize=(18, 6))  # Adjust the figure size

for i, role in enumerate(roles):
    plt.subplot(1, 3, i + 1)  # Create subplots for each role
    plt.title(f'Priority of Hand Hygiene at {role}')

    # Filter out categories with 0% priority
    non_zero_data = [data[i][j] for j in range(len(data[i])) if data[i][j] > 0]
    non_zero_labels = [priority_labels[j] for j in range(len(data[i])) if data[i][j] > 0]

    plt.pie(non_zero_data, labels=non_zero_labels, autopct='%1.1f%%', startangle=90)
    plt.axis('equal')

plt.tight_layout()
plt.show()

# %%
# Survey q7: How many seconds do you usually spend in hand hygiene using alcohol-based hand rubs?

import matplotlib.pyplot as plt
import numpy as np

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
seconds_10_or_less = [21.4, 23, 54.5]
seconds_10_to_15 = [28.5, 38.4, 18.9]
seconds_15_to_20 = [35.7, 23, 0]
seconds_greater_than_20 = [14.3, 15.3, 27.3]

x = np.arange(len(roles))
width = 0.35

fig, ax = plt.subplots()

ax.bar(x, seconds_10_or_less, width, label='10 seconds or less')
ax.bar(x, seconds_10_to_15, width, bottom=seconds_10_or_less, label='10 to 15 seconds')
ax.bar(x, seconds_15_to_20, width, bottom=np.array(seconds_10_or_less) + np.array(seconds_10_to_15), label='15 to 20 seconds')
ax.bar(x, seconds_greater_than_20, width, bottom=np.array(seconds_10_or_less) + np.array(seconds_10_to_15) + np.array(seconds_15_to_20), label='> 20 seconds')

ax.set_ylabel('Percentage')
ax.set_title('Time Spent in Hand Hygiene by Role (In Percentage)')
ax.set_xticks(x)
ax.set_xticklabels(roles)
ax.legend(title='Time')

fig.tight_layout()

plt.show()

# %%
# Survey q7: How many seconds do you usually spend in hand hygiene using alcohol-based hand rubs?

import matplotlib.pyplot as plt
import numpy as np

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
seconds_10_or_less = [21.4, 23.1, 54.1]
seconds_10_to_15 = [28.5, 38.5, 18.8]
seconds_15_to_20 = [35.7, 23.1, 0]
seconds_greater_than_20 = [14.3, 15.3, 27.1]

x = np.arange(len(roles))
width = 0.2

fig, ax = plt.subplots()

rects1 = ax.bar(x - 1.5*width, seconds_10_or_less, width, label='10 seconds or less')
rects2 = ax.bar(x - 0.5*width, seconds_10_to_15, width, label='10 to 15 seconds')
rects3 = ax.bar(x + 0.5*width, seconds_15_to_20, width, label='15 to 20 seconds')
rects4 = ax.bar(x + 1.5*width, seconds_greater_than_20, width, label='> 20 seconds')

ax.set_ylabel('Percentage')
ax.set_xlabel('Role')
ax.set_title('Time Spent in Hand Hygiene by Role (In Percentage)')
ax.set_xticks(x)
ax.set_xticklabels(roles)
ax.legend(title='Time Intervals')

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)

fig.tight_layout()

plt.show()

# %%
# Survey q7: How many seconds do you usually spend in hand hygiene using alcohol-based hand rubs?

import matplotlib.pyplot as plt

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
time_labels = ['10 seconds or less', '10 to 15 seconds', '15 to 20 seconds', '> 20 seconds']

# Time data for each role
data = [
    [21.4, 28.5, 35.7, 14.3],
    [23, 38.4, 23, 15.3],
    [54.5, 18.9, 0, 27.3]
]

# Create pie charts for each role
plt.figure(figsize=(18, 6))  # Adjust the figure size

for i, role in enumerate(roles):
    plt.subplot(1, 3, i + 1)  # Create subplots for each role
    plt.title(f'Time Spent on Hand Hygiene for {role}')

    # Filter out categories with 0% time
    non_zero_data = [data[i][j] for j in range(len(data[i])) if data[i][j] > 0]
    non_zero_labels = [time_labels[j] for j in range(len(data[i])) if data[i][j] > 0]

    plt.pie(non_zero_data, labels=non_zero_labels, autopct='%1.1f%%', startangle=90)
    plt.axis('equal')

plt.tight_layout()
plt.show()

# %%
# Survey q8: Alcohol-based hand rubs are effective in preventing transmission of the following (select all that apply)

import seaborn as sns
import matplotlib.pyplot as plt

# Data
data = [
    [100, 100, 92.8, 57.1, 100, 57.1],
    [69.2, 84.6, 84.6, 53.8, 76.9, 61.5],
    [81.8, 100, 72.7, 18.9, 81.8, 45.4]
]

roles = ['PGY-1', 'PGY-2', 'PGY-3']
pathogens = ['ESBL', 'Enterococci', 'Norovirus', 'C diff', 'MRSA', 'Cryptosporidiosis']

# Create a heatmap
sns.set(font_scale=1)
ax = sns.heatmap(data, annot=True, fmt=".1f", cmap="YlGnBu", xticklabels=pathogens, yticklabels=roles)
ax.set_xlabel('Pathogens')
ax.set_ylabel('Roles')
ax.set_title('Effectiveness of Alcohol-Based Hand Rubs (In Percentage)')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data
data = [
    [100, 100, 92.8, 57.1, 100, 57.1],
    [69.2, 84.6, 84.6, 53.8, 76.9, 61.5],
    [81.8, 100, 72.7, 18.9, 81.8, 45.4]
]

roles = ['PGY-1', 'PGY-2', 'PGY-3']
pathogens = ['ESBL', 'Enterococci', 'Norovirus', 'C diff', 'MRSA', 'Cryptosporidiosis']

# Create a heatmap with a different colormap (e.g., 'coolwarm')
sns.set(font_scale=1)
fig, ax = plt.subplots(figsize=(12, 8))  # Larger graph size (adjust the width and height as needed)
ax = sns.heatmap(data, annot=True, fmt=".1f", cmap="coolwarm", xticklabels=pathogens, yticklabels=roles)
ax.set_xlabel('Pathogens')
ax.set_ylabel('Roles')
ax.set_title('Effectiveness of Alcohol-Based Hand Rubs (In Percentage)')

# Prevent x-axis label rotation
plt.xticks(rotation=0)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data
data = [
    [100, 100, 92.8, 57.1, 100, 57.1],
    [69.2, 84.6, 84.6, 53.8, 76.9, 61.5],
    [81.8, 100, 72.7, 18.9, 81.8, 45.4]
]

roles = ['PGY-1', 'PGY-2', 'PGY-3']
pathogens = ['ESBL', 'Enterococci', 'Norovirus', 'C diff', 'MRSA', 'Cryptosporidiosis']

# Create a heatmap with the 'RdPu' colormap
sns.set(font_scale=1)
fig, ax = plt.subplots(figsize=(12, 8))  # Larger graph size (adjust the width and height as needed)
ax = sns.heatmap(data, annot=True, fmt=".1f", cmap="RdPu", xticklabels=pathogens, yticklabels=roles)
ax.set_xlabel('Pathogens')
ax.set_ylabel('Roles')
ax.set_title('Effectiveness of Alcohol-Based Hand Rubs (In Percentage)')

# Prevent x-axis label rotation
plt.xticks(rotation=0)

plt.show()

# %%
# Survey q9: In your opinion, how effective would the following actions be to improve hand hygiene in your institution?

import matplotlib.pyplot as plt
import numpy as np

# Define the actions and corresponding effectiveness percentages
actions = [
    "Physician support",
    "Hand rub available",
    "Posters displayed",
    "Workers receive feedback",
    "You perform hygiene",
    "Patients and families remind"
]

effectiveness = {
    "Very ineffective": [0, 0, 0, 0, 0, 0],
    "Ineffective": [0, 0, 7.1, 7.1, 0, 0],
    "Not sure/Neutral": [14.3, 0, 0, 21.4, 14.3, 21.4],
    "Effective": [35.7, 21.4, 50, 35.7, 35.7, 35.7],
    "Very effective": [50, 78.5, 35.7, 35.7, 50, 42.8]
}

# Prepare data for plotting
x = np.arange(len(actions))
width = 0.15

# Create subplots for each category of effectiveness
fig, ax = plt.subplots(figsize=(14, 8))  # Adjust the figure size

for i, (effectiveness_label, values) in enumerate(effectiveness.items()):
    ax.bar(x + i * width, values, width, label=effectiveness_label)

ax.set_xlabel('Actions')
ax.set_ylabel('Effectiveness')
ax.set_title('(PGY-1 Effectiveness of Actions to Improve Hand Hygiene')
ax.set_xticks(x + 2 * width)
ax.set_xticklabels(actions, ha="center")
ax.legend(title='Effectiveness')

# Add labels outside the graph
for i, (effectiveness_label, values) in enumerate(effectiveness.items()):
    for j, value in enumerate(values):
        if value > 0:  # Only display non-zero percentages
            ax.annotate(f"{value:.1f}%", (x[j] + i * width, value + 2), ha='center', va='bottom', rotation=90)

plt.tight_layout()
plt.show()

# %%
# Survey q9: In your opinion, how effective would the following actions be to improve hand hygiene in your institution?

import matplotlib.pyplot as plt
import numpy as np

# Define the actions and corresponding effectiveness percentages
actions = [
    "Physician support",
    "Hand rub available",
    "Posters displayed",
    "Workers receive feedback",
    "You perform hygiene",
    "Patients and families remind"
]

effectiveness = {
    "Very ineffective": [7.6, 0, 7.6, 0, 0, 7.6],
    "Ineffective": [7.6, 15.3, 7.6, 7.6, 7.6, 23],
    "Not sure/Neutral": [30.7, 0, 23, 15.3, 0, 30.7],
    "Effective": [38.4, 30.7, 46.1, 69.2, 76.9, 23],
    "Very effective": [23, 53.8, 23, 15.3, 23, 23]
}

# Prepare data for plotting
x = np.arange(len(actions))
width = 0.15

# Create subplots for each category of effectiveness
fig, ax = plt.subplots(figsize=(14, 8))  # Adjust the figure size

for i, (effectiveness_label, values) in enumerate(effectiveness.items()):
    ax.bar(x + i * width, values, width, label=effectiveness_label)

ax.set_xlabel('Actions')
ax.set_ylabel('Effectiveness')
ax.set_title('(PGY-2) Effectiveness of Actions to Improve Hand Hygiene')
ax.set_xticks(x + 2 * width)
ax.set_xticklabels(actions, ha="center")
ax.legend(title='Effectiveness')

# Add labels outside the graph
for i, (effectiveness_label, values) in enumerate(effectiveness.items()):
    for j, value in enumerate(values):
        if value > 0:  # Only display non-zero percentages
            ax.annotate(f"{value:.1f}%", (x[j] + i * width, value + 2), ha='center', va='bottom', rotation=90)

plt.tight_layout()
plt.show()

# %%
# Survey q9: In your opinion, how effective would the following actions be to improve hand hygiene in your institution?

import matplotlib.pyplot as plt
import numpy as np

# Define the actions and corresponding effectiveness percentages
actions = [
    "Physician support",
    "Hand rub available",
    "Posters displayed",
    "Workers receive feedback",
    "You perform hygiene",
    "Patients and families remind"
]

effectiveness = {
    "Very ineffective": [0, 0, 0, 0, 0, 0],
    "Ineffective": [0, 0, 9, 0, 0, 9],
    "Not sure/Neutral": [27.3, 9, 27.3, 45.4, 18.9, 27.3],
    "Effective": [45.4, 54.5, 45.4, 54.5, 63.6, 63.6],
    "Very effective": [27.3, 36.3, 18.9, 0, 18.9, 0]
}

# Prepare data for plotting
x = np.arange(len(actions))
width = 0.15

# Create subplots for each category of effectiveness
fig, ax = plt.subplots(figsize=(14, 8))  # Adjust the figure size

for i, (effectiveness_label, values) in enumerate(effectiveness.items()):
    ax.bar(x + i * width, values, width, label=effectiveness_label)

ax.set_xlabel('Actions')
ax.set_ylabel('Effectiveness')
ax.set_title('(PGY-3) Effectiveness of Actions to Improve Hand Hygiene')
ax.set_xticks(x + 2 * width)
ax.set_xticklabels(actions, ha="center")
ax.legend(title='Effectiveness')

# Add labels outside the graph
for i, (effectiveness_label, values) in enumerate(effectiveness.items()):
    for j, value in enumerate(values):
        if value > 0:  # Only display non-zero percentages
            ax.annotate(f"{value:.1f}%", (x[j] + i * width, value + 2), ha='center', va='bottom', rotation=90)

plt.tight_layout()
plt.show()

# %%
# Survey q10: What importance do your department leaders attach to the fact that you perform optimal hand hygiene?

import matplotlib.pyplot as plt
import numpy as np

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
importance_levels = [
    'Not important at all',
    'Slightly important',
    'Of average importance',
    'Important',
    'Very important'
]
data = [
    [0, 0, 7.1, 50.1, 42.8],
    [0, 15.3, 23.1, 30.8, 30.8],
    [0, 0, 27.1, 54.1, 18.8]
]

x = np.arange(len(roles))
height = 0.5

colors = ['#FF9999', '#66B3FF', '#99FF99', '#FFCC99', '#FFD700']

fig, ax = plt.subplots(figsize=(10, 6))

bottoms = np.zeros(len(roles))

for i, level in enumerate(importance_levels):
    values = [item[i] for item in data]
    filtered_values = [val for val in values if val != 0]
    if filtered_values:
        ax.barh(x, values, height, label=level, color=colors[i], left=bottoms)
        for j, val in enumerate(values):
            if val != 0:
                ax.text(bottoms[j] + val/2, j, f'{val:.1f}%', ha='center', va='center', color='black')
        bottoms += values

ax.set_xlabel('Percentage')
ax.set_title('Importance of Optimal Hand Hygiene by Role (In Percentage)')
ax.set_yticks(x)
ax.set_yticklabels(roles)
ax.legend(title='Importance Levels', bbox_to_anchor=(1, 1))

fig.tight_layout()

plt.show()

# %%
# Survey q10: What importance do your department leaders attach to the fact that you perform optimal hand hygiene?

import matplotlib.pyplot as plt

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
importance_levels = ['Not important at all', 'Slightly important', 'Of average importance', 'Important', 'Very important']
values = [
    [0, 0, 7.1, 50, 42.8],
    [0, 15.3, 23, 30.7, 30.7],
    [0, 0, 27.3, 54.5, 18.9]
]

# Create a pie chart for each role
plt.figure(figsize=(18, 6))  # Adjust the figure size

for i, role in enumerate(roles):
    data = values[i]
    non_zero_data = [data[j] for j in range(len(data)) if data[j] > 0]
    non_zero_labels = [importance_levels[j] for j in range(len(data)) if data[j] > 0]
    plt.subplot(1, 3, i + 1)  # Create subplots for each role
    plt.pie(non_zero_data, labels=non_zero_labels, autopct='%1.1f%%', startangle=140)
    plt.title(f'Importance of Optimal Hand Hygiene for {role}')

    # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.axis('equal')

plt.tight_layout()
plt.show()

# %%
# Survey q11: What importance do your colleagues attach to the fact that you perform optimal hand hygiene?

import matplotlib.pyplot as plt
import numpy as np

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
importance_levels = [
    'Not important at all',
    'Slightly important',
    'Of average importance',
    'Important',
    'Very important'
]
data = [
    [0, 0, 14.3, 50, 35.7],
    [0, 23.1, 15.3, 30.8, 30.8],
    [0, 8.9, 27.1, 45.1, 18.8]
]

x = np.arange(len(roles))
width = 0.5

colors = ['#FF9999', '#66B3FF', '#99FF99', '#FFCC99', '#FFD700']

fig, ax = plt.subplots(figsize=(10, 6))

bottoms = np.zeros(len(roles))

for i, level in enumerate(importance_levels):
    values = [item[i] for item in data]
    filtered_values = [val for val in values if val != 0]
    if filtered_values:
        ax.bar(x, values, width, label=level, color=colors[i], bottom=bottoms)
        for j, val in enumerate(values):
            if val != 0:
                ax.text(j, bottoms[j] + val/2, f'{val:.1f}%', ha='center', va='center', color='black')
        bottoms += values

ax.set_ylabel('Percentage')
ax.set_title('Importance of Optimal Hand Hygiene by Role (In Percentage)')
ax.set_xticks(x)
ax.set_xticklabels(roles)
ax.legend(title='Importance Levels', bbox_to_anchor=(1, 1))

fig.tight_layout()

plt.xticks(rotation=0, ha='center')
plt.show()

# %%
# Survey q11: What importance do your colleagues attach to the fact that you perform optimal hand hygiene?

import matplotlib.pyplot as plt

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
importance_levels = ['Not important at all', 'Slightly important', 'Of average importance', 'Important', 'Very important']
values = [
    [0, 0, 14.3, 50, 35.7],
    [0, 23, 15.3, 30.7, 30.7],
    [0, 9, 27.3, 45.4, 18.9]
]

# Create a pie chart for each role
plt.figure(figsize=(18, 6))  # Adjust the figure size

for i, role in enumerate(roles):
    data = values[i]
    non_zero_data = [data[j] for j in range(len(data)) if data[j] > 0]
    non_zero_labels = [importance_levels[j] for j in range(len(data)) if data[j] > 0]
    plt.subplot(1, 3, i + 1)  # Create subplots for each role
    plt.pie(non_zero_data, labels=non_zero_labels, autopct='%1.1f%%', startangle=140)
    plt.title(f'Importance of Optimal Hand Hygiene for {role}')

    # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.axis('equal')

plt.tight_layout()
plt.show()

# %%
# Survey q12: What importance do patients attach to the fact that you perform optimal hand hygiene?

import matplotlib.pyplot as plt
import numpy as np

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
importance_levels = [
    'Not important at all',
    'Slightly important',
    'Of average importance',
    'Important',
    'Very important'
]
data = [
    [7.1, 28.6, 35.8, 0, 28.6],
    [7.6, 30.8, 15.4, 30.8, 15.4],
    [0, 9.0, 9.0, 54.6, 27.4]
]

x = np.arange(len(roles))
height = 0.5

colors = ['#FF9999', '#66B3FF', '#99FF99', '#FFCC99', '#FFD700']

fig, ax = plt.subplots(figsize=(10, 6))

bottoms = np.zeros(len(roles))

for i, level in enumerate(importance_levels):
    values = [item[i] for item in data]
    filtered_values = [val for val in values if val != 0]
    if filtered_values:
        ax.barh(x, values, height, label=level, color=colors[i], left=bottoms)
        for j, val in enumerate(values):
            if val != 0:
                ax.text(bottoms[j] + val/2, j, f'{val:.1f}%', ha='center', va='center', color='black')
        bottoms += values

ax.set_xlabel('Percentage')
ax.set_title('Importance of Optimal Hand Hygiene by Role (In Percentage)')
ax.set_yticks(x)
ax.set_yticklabels(roles)
ax.legend(title='Importance Levels', bbox_to_anchor=(1, 1))

fig.tight_layout()

plt.show()

# %%
# Survey q12: What importance do patients attach to the fact that you perform optimal hand hygiene?

import matplotlib.pyplot as plt

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
importance_levels = ['Not important at all', 'Slightly important', 'Of average importance', 'Important', 'Very important']
values = [
    [7.1, 28.5, 35.7, 0, 28.5],
    [7.6, 30.7, 15.3, 30.7, 15.3],
    [0, 9, 9, 54.5, 27.3]
]

# Create a pie chart for each role
plt.figure(figsize=(18, 6))  # Adjust the figure size

for i, role in enumerate(roles):
    data = values[i]
    non_zero_data = [data[j] for j in range(len(data)) if data[j] > 0]
    non_zero_labels = [importance_levels[j] for j in range(len(data)) if data[j] > 0]
    plt.subplot(1, 3, i + 1)  # Create subplots for each role
    plt.pie(non_zero_data, labels=non_zero_labels, autopct='%1.1f%%', startangle=140)
    plt.title(f'Importance of Optimal Hand Hygiene for {role}')

    # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.axis('equal')

plt.tight_layout()
plt.show()

# %%
# Survey q13: How often do you need to be reminded of hand hygiene during rounds?

import matplotlib.pyplot as plt
import numpy as np

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
frequency_levels = [
    'Never',
    'Rarely',
    'Sometimes',
    'Often',
    'Always'
]
data = [
    [21.4, 50.1, 0, 0, 28.5],
    [30.8, 38.5, 23.1, 7.6, 0],
    [0, 45.4, 27.3, 27.3, 0]
]

x = np.arange(len(roles))
width = 0.15

colors = ['#FF9999', '#66B3FF', '#99FF99', '#FFCC99', '#FFD700']

fig, ax = plt.subplots(figsize=(10, 6))

for i, level in enumerate(frequency_levels):
    values = [item[i] for item in data]
    filtered_values = [val for val in values if val != 0]
    if filtered_values:
        ax.bar(x + i*width, values, width, label=level, color=colors[i])
        for j, val in enumerate(values):
            if val != 0:
                ax.text(j + i*width, val + 2, f'{val:.1f}%', ha='center', va='bottom', color='black')

ax.set_ylabel('Percentage')
ax.set_title('Frequency of Reminders for Hand Hygiene During Rounds (In Percentage)')
ax.set_xticks(x + (width*2))
ax.set_xticklabels(roles)
ax.legend(title='Frequency Levels', bbox_to_anchor=(1, 1))

fig.tight_layout()

plt.xticks(rotation=0, ha='center')
plt.show()

# %%
# Survey q13: How often do you need to be reminded of hand hygiene during rounds?

import matplotlib.pyplot as plt

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
reminder_levels = ['Never', 'Rarely', 'Sometimes', 'Often', 'Always']
values = [
    [21.4, 50, 0, 0, 28.5],
    [30.7, 38.4, 23, 7.6, 0],
    [0, 45.4, 27.3, 27.3, 0]
]

# Create a pie chart for each role
plt.figure(figsize=(18, 6))  # Adjust the figure size

for i, role in enumerate(roles):
    data = values[i]
    non_zero_data = [data[j] for j in range(len(data)) if data[j] > 0]
    non_zero_labels = [reminder_levels[j] for j in range(len(data)) if data[j] > 0]
    plt.subplot(1, 3, i + 1)  # Create subplots for each role
    plt.pie(non_zero_data, labels=non_zero_labels, autopct='%1.1f%%', startangle=140)
    plt.title(f'Frequency of Hand Hygiene Reminders for {role}')

    # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.axis('equal')

plt.tight_layout()
plt.show()

# %%
# Survey q14: Who do you want to remind you to perform hand hygiene in case you forget? (Check all that apply)

import matplotlib.pyplot as plt
import numpy as np

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
reminders = ['Unit manager', 'Nurse', 'Resident physician', 'Attending physician', 'Patient/Family']
data = [
    [64.3, 64.3, 78.5, 57.1, 35.7],
    [46.1, 76.9, 92.3, 61.5, 30.7],
    [27.3, 36.3, 9, 54.5, 0]
]

x = np.arange(len(roles))
width = 0.5

colors = ['#FF9999', '#66B3FF', '#99FF99', '#FFCC99', '#FFD700']

fig, ax = plt.subplots(figsize=(10, 6))

bottoms = np.zeros(len(roles))

for i, reminder in enumerate(reminders):
    ax.barh(x, [item[i] for item in data], width, label=reminder, color=colors[i], left=bottoms)
    for j, val in enumerate([item[i] for item in data]):
        if val != 0:
            ax.text(bottoms[j] + val/2, j, f'{val:.1f}%', ha='center', va='center', color='black')
    bottoms += [item[i] for item in data]

ax.set_xlabel('Percentage')
ax.set_title('Desired Reminders for Hand Hygiene in Case of Forgetting (In Percentage)')
ax.set_yticks(x)
ax.set_yticklabels(roles)
ax.legend(title='Reminders', bbox_to_anchor=(1, 1))

fig.tight_layout()

plt.show()

# %%
# Survey q15: Are you aware of a "secret shopper" project at your institution which involves unidentified employees monitoring your hand hygiene practices each time you enter or exit a patient's room?

import matplotlib.pyplot as plt
import numpy as np

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
awareness_levels = ['No', 'Yes', 'Not sure']
data = [
    [14.3, 50.0, 35.7],
    [23.0, 46.2, 30.8],
    [36.1, 45.1, 18.8]
]

x = np.arange(len(roles))
width = 0.5

colors = ['#FF9999', '#66B3FF', '#FFD700']

fig, ax = plt.subplots(figsize=(10, 6))

bottoms = np.zeros(len(roles))

for i, awareness in enumerate(awareness_levels):
    ax.barh(x, [item[i] for item in data], width, label=awareness, color=colors[i], left=bottoms)
    for j, val in enumerate([item[i] for item in data]):
        if val != 0:
            ax.text(bottoms[j] + val/2, j, f'{val:.1f}%', ha='center', va='center', color='black')
    bottoms += [item[i] for item in data]

ax.set_xlabel('Percentage')
ax.set_title('Awareness of "Secret Shopper" Project for Monitoring Hand Hygiene (In Percentage)')
ax.set_yticks(x)
ax.set_yticklabels(roles)
ax.legend(title='Awareness Levels', bbox_to_anchor=(1, 1))

fig.tight_layout()

plt.show()

# %%
# Survey q15: Are you aware of a "secret shopper" project at your institution which involves unidentified employees monitoring your hand hygiene practices each time you enter or exit a patient's room?

import matplotlib.pyplot as plt

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
awareness_levels = ['No', 'Yes', 'Not sure']
values = [
    [14.3, 50, 35.7],
    [23, 46.1, 30.7],
    [36.3, 45.4, 18.9]
]

# Create a pie chart for each role
plt.figure(figsize=(18, 6))  # Adjust the figure size

for i, role in enumerate(roles):
    data = values[i]
    non_zero_data = [data[j] for j in range(len(data)) if data[j] > 0]
    non_zero_labels = [awareness_levels[j] for j in range(len(data)) if data[j] > 0]
    plt.subplot(1, 3, i + 1)  # Create subplots for each role
    plt.pie(non_zero_data, labels=non_zero_labels, autopct='%1.1f%%', startangle=140)
    plt.title(f'Awareness of "Secret Shopper" Project for {role}')

    # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.axis('equal')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
awareness_levels = ['No', 'Yes', 'Not sure']
data = [
    [14.3, 50, 35.7],
    [23, 46.1, 30.7],
    [36.3, 45.4, 18.9]
]

x = np.arange(len(roles))
width = 0.2

colors = ['#FF9999', '#66B3FF', '#FFD700']

fig, ax = plt.subplots(figsize=(10, 6))

for i, awareness in enumerate(awareness_levels):
    ax.bar(x + (i - 1) * width, [item[i] for item in data], width, label=awareness, color=colors[i])
    for j, val in enumerate([item[i] for item in data]):
        if val != 0:
            ax.text(j + (i - 1) * width, val + 1, f'{val:.1f}%', ha='center', va='bottom', color='black')

ax.set_ylabel('Percentage')
ax.set_title('Awareness of "Secret Shopper" Project for Monitoring Hand Hygiene (In Percentage)')
ax.set_xticks(x)
ax.set_xticklabels(roles)
ax.legend(title='Awareness Levels', bbox_to_anchor=(1, 1))

fig.tight_layout()

plt.show()

# %%
# Survey q16: Have you or your team ever had a "secret shopper" report you for not practicing hand hygiene during rounds?

import matplotlib.pyplot as plt
import numpy as np

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
report_levels = ['No', 'Yes', 'Not sure']
data = [
    [64.3, 0, 35.7],
    [61.6, 15.3, 23.0],
    [45.5, 9.0, 45.5]
]

x = np.arange(len(roles))
width = 0.2

colors = ['#FF9999', '#66B3FF', '#FFD700']

fig, ax = plt.subplots(figsize=(10, 6))

for i, report in enumerate(report_levels):
    ax.bar(x + (i - 1) * width, [item[i] for item in data], width, label=report, color=colors[i])
    for j, val in enumerate([item[i] for item in data]):
        if val != 0:
            ax.text(j + (i - 1) * width, val + 1, f'{val:.1f}%', ha='center', va='bottom', color='black')

ax.set_ylabel('Percentage')
ax.set_title('"Secret Shopper" Reports for Not Practicing Hand Hygiene During Rounds (In Percentage)')
ax.set_xticks(x)
ax.set_xticklabels(roles)
ax.legend(title='Report Levels', bbox_to_anchor=(1, 1))

fig.tight_layout()

plt.show()

# %%
# Survey q16: Have you or your team ever had a "secret shopper" report you for not practicing hand hygiene during rounds?

import matplotlib.pyplot as plt

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
report_levels = ['No', 'Yes', 'Not sure']
values = [
    [64.3, 0, 35.7],
    [61.5, 15.3, 23],
    [45.4, 9, 45.4]
]

# Create a pie chart for each role
plt.figure(figsize=(18, 6))  # Adjust the figure size

for i, role in enumerate(roles):
    data = values[i]
    non_zero_data = [data[j] for j in range(len(data)) if data[j] > 0]
    non_zero_labels = [report_levels[j] for j in range(len(data)) if data[j] > 0]
    plt.subplot(1, 3, i + 1)  # Create subplots for each role
    plt.pie(non_zero_data, labels=non_zero_labels, autopct='%1.1f%%', startangle=140)
    plt.title(f"Secret Shopper Reports for {role}")

    # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.axis('equal')

plt.tight_layout()
plt.show()

# %%
# Survey q17: How much do the following barriers interfere with your optimal hand hygiene?

import matplotlib.pyplot as plt
import numpy as np

# Define the barriers and corresponding percentages
barriers = [
    "Not convenient",
    "Out of product",
    "Product dissatisfaction",
    "Too busy",
    "Forget",
    "Skin conditions",
    "Unsure of need"
]

percentages = {
    "Never": [35.7, 28.5, 57.1, 42.8, 7.1, 28.5, 64.3],
    "Rarely": [21.4, 42.8, 14.3, 28.5, 42.8, 28.5, 14.3],
    "Sometimes": [42.8, 14.3, 21.4, 28.5, 50, 35.7, 21.4],
    "Often": [0, 7.1, 7.1, 0, 0, 0, 0],
    "Always": [0, 7.1, 0, 0, 0, 7.1, 0]
}

# Prepare data for plotting
x = np.arange(len(barriers))
width = 0.15

# Create subplots for each barrier frequency
fig, ax = plt.subplots(figsize=(14, 8))  # Increase the figsize here

for i, (frequency_label, values) in enumerate(percentages.items()):
    ax.bar(x + i * width, values, width, label=frequency_label)

ax.set_xlabel('Barriers')
ax.set_ylabel('Percentage')
ax.set_title('(PGY-1) Barriers to Optimal Hand Hygiene')
ax.set_xticks(x + 2 * width)
ax.set_xticklabels(barriers, ha="center")  # Rotate x-axis labels by 90 degrees
ax.legend(title='Frequency')

# Add labels outside the graph
for i, (frequency_label, values) in enumerate(percentages.items()):
    for j, value in enumerate(values):
        if value > 0:  # Only display non-zero percentages
            ax.annotate(f"{value:.1f}%", (x[j] + i * width, value + 2), ha='center', va='bottom', rotation=90)

plt.tight_layout()
plt.show()

# %%
# Survey q17: How much do the following barriers interfere with your optimal hand hygiene?

import matplotlib.pyplot as plt
import numpy as np

# Define the barriers and corresponding percentages
barriers = [
    "Not convenient",
    "Out of product",
    "Product dissatisfaction",
    "Too busy",
    "Forget",
    "Skin conditions",
    "Unsure of need"
]

percentages = {
    "Never": [53.8, 23, 61.5, 30.7, 23, 61.5, 84.6],
    "Rarely": [38.4, 46.1, 23, 30.7, 30.7, 23, 15.3],
    "Sometimes": [7.6, 15.3, 15.3, 38.4, 38.4, 7.6, 0],
    "Often": [7.6, 23, 7.6, 7.6, 15.3, 15.3, 7.6],
    "Always": [0, 0, 0, 0, 0, 0, 0]
}

# Prepare data for plotting
x = np.arange(len(barriers))
width = 0.15

# Create subplots for each barrier frequency
fig, ax = plt.subplots(figsize=(14, 8))  # Larger size

for i, (frequency_label, values) in enumerate(percentages.items()):
    ax.bar(x + i * width, values, width, label=frequency_label)

ax.set_xlabel('Barriers')
ax.set_ylabel('Percentage')
ax.set_title('(PGY-2) Barriers to Optimal Hand Hygiene')
ax.set_xticks(x + 2 * width)
ax.set_xticklabels(barriers, ha="center")  # Rotate x-axis labels by 90 degrees
ax.legend(title='Frequency')

# Add labels outside the graph
for i, (frequency_label, values) in enumerate(percentages.items()):
    for j, value in enumerate(values):
        if value > 0:  # Only display non-zero percentages
            ax.annotate(f"{value:.1f}%", (x[j] + i * width, value + 2), ha='center', va='bottom', rotation=90)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the barriers and corresponding percentages
barriers = [
    "Not convenient",
    "Out of product",
    "Product dissatisfaction",
    "Too busy",
    "Forget",
    "Skin conditions",
    "Unsure of need"
]

percentages = {
    "Never": [36.3, 54.5, 54.5, 36.3, 18.9, 63.6, 63.6],
    "Rarely": [36.3, 18.9, 27.3, 18.9, 36.3, 18.9, 27.3],
    "Sometimes": [18.9, 27.3, 9, 36.3, 18.9, 18.9, 0],
    "Often": [9, 0, 9, 9, 27.3, 0, 9],
    "Always": [0, 0, 0, 0, 0, 0, 0]
}

# Prepare data for plotting
x = np.arange(len(barriers))
width = 0.15

# Create subplots for each barrier frequency
fig, ax = plt.subplots(figsize=(14, 8))  # Larger graph size

for i, (frequency_label, values) in enumerate(percentages.items()):
    ax.bar(x + i * width, values, width, label=frequency_label)

ax.set_xlabel('Barriers')
ax.set_ylabel('Percentage')
ax.set_title('(PGY-3) Barriers to Optimal Hand Hygiene')
ax.set_xticks(x + 2 * width)
ax.set_xticklabels(barriers, ha="center")  # Place X-axis labels in the middle
ax.legend(title='Frequency')

# Add labels outside the graph
for i, (frequency_label, values) in enumerate(percentages.items()):
    for j, value in enumerate(values):
        if value > 0:  # Only display non-zero percentages
            ax.annotate(f"{value:.1f}%", (x[j] + i * width, value + 2), ha='center', va='bottom', rotation=90)

plt.tight_layout()
plt.show()

# %%
# Survey q18: Please check this box if there are currently NO BARRIERS.

import matplotlib.pyplot as plt
import numpy as np

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
options = ['Yes', 'No']
data = [
    [50, 50],
    [30.7, 69.3],
    [18.8, 81.2]
]

x = np.arange(len(roles))
width = 0.35

fig, ax = plt.subplots(figsize=(8, 6))

colors = ['#FF9999', '#66B3FF']

for i, option in enumerate(options):
    ax.bar(x + i * width, [item[i] for item in data], width, label=option, color=colors[i])
    for j, val in enumerate([item[i] for item in data]):
        ax.annotate('{:.1f}%'.format(val),
                    xy=(x[j] + i * width, val),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

ax.set_ylabel('Percentage')
ax.set_title('Barriers to Hand Hygiene by Role (In Percentage)')
ax.set_xticks(x + width / 2)
ax.set_xticklabels(roles)
ax.legend(title='Options', bbox_to_anchor=(1, 1))

fig.tight_layout()

plt.xticks(rotation=0, ha='center')
plt.show()

# %%
# Survey q18: Please check this box if there are currently NO BARRIERS.

import matplotlib.pyplot as plt

# Data
roles = ['PGY-1', 'PGY-2', 'PGY-3']
barrier_options = ['Yes', 'No']
values = [
    [50, 50],
    [30.7, 69.2],
    [18.9, 81.8]
]

# Create pie charts for each role
plt.figure(figsize=(18, 6))  # Adjust the figure size

for i, role in enumerate(roles):
    data = values[i]
    plt.subplot(1, 3, i + 1)  # Create subplots for each role
    plt.title(f'Barriers for {role}')

    non_zero_data = [data[j] for j in range(len(data)) if data[j] > 0]
    non_zero_labels = ['Yes', 'No'][:len(non_zero_data)]
    plt.pie(non_zero_data, labels=non_zero_labels, autopct='%1.1f%%', startangle=140)
    plt.axis('equal')

plt.tight_layout()
plt.show()

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Define the data as a 2x2 contingency table
observed = np.array([[42, 100 - 42], [8, 100 - 8]])

# Perform the chi-squared test
chi2, p, _, _ = chi2_contingency(observed)

print("Chi-squared statistic:", chi2)
print("P-value:", p)
# Out:
# Chi-squared statistic: 29.04
# P-value: 7.089913521079198e-08

# %%
import numpy as np
from scipy import stats

# Define the data as arrays for each role (PGY-1, PGY-2, PGY-3)
pgy1 = [0, 0, 21.4, 35.7, 42.8]
pgy2 = [0, 0, 23.0, 46.1, 30.7]
pgy3 = [0, 27.3, 18.9, 45.4, 9.0]

# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(pgy1, pgy2, pgy3)

print("F-statistic:", f_statistic)
print("P-value:", p_value)

# Determine if the p-value is significant (e.g., alpha = 0.05)
alpha = 0.05
if p_value < alpha:
    print("The differences among groups are statistically significant.")
else:
    print("The differences among groups are not statistically significant.")
# Out:
# F-statistic: 0.00010378808294306552
# P-value: 0.9998962182004137
# The differences among groups are not statistically significant.

# %%
import numpy as np
from scipy.stats import f

# Sample data for PGY-1, PGY-2, PGY-3
pgy1 = [0, 0, 21.4, 35.7, 42.8]
pgy2 = [0, 0, 23.0, 46.1, 30.7]
pgy3 = [0, 27.3, 18.9, 45.4, 9.0]

# Step 1: Calculate the Sample Means
mean_pgy1 = np.mean(pgy1)
mean_pgy2 = np.mean(pgy2)
mean_pgy3 = np.mean(pgy3)

# Step 2: Calculate the Overall Mean
overall_mean = np.mean(np.concatenate((pgy1, pgy2, pgy3)))

# Step 3: Calculate the Sum of Squares for Between Groups (SSB)
ssb = (
    len(pgy1) * (mean_pgy1 - overall_mean) ** 2 +
    len(pgy2) * (mean_pgy2 - overall_mean) ** 2 +
    len(pgy3) * (mean_pgy3 - overall_mean) ** 2
)

# Step 4: Calculate the Sum of Squares for Within Groups (SSW)
ssw = (
    np.sum((pgy1 - mean_pgy1) ** 2) +
    np.sum((pgy2 - mean_pgy2) ** 2) +
    np.sum((pgy3 - mean_pgy3) ** 2)
)

# Step 5: Calculate the Degrees of Freedom (df)
df_between = 2  # Three groups - 1
df_within = len(pgy1) + len(pgy2) + len(pgy3) - 3  # Total data points - Number of groups

# Step 6: Calculate the Mean Square for Between Groups (MSB)
msb = ssb / df_between

# Step 7: Calculate the Mean Square for Within Groups (MSW)
msw = ssw / df_within

# Step 8: Calculate the F-statistic
f_statistic = msb / msw

# Step 9: Determine the p-value
p_value = 1 - f.cdf(f_statistic, df_between, df_within)

# Step 10: Compare the p-value to the Significance Level (e.g., 0.05)
alpha = 0.05
if p_value < alpha:
    print("There are statistically significant differences among the groups.")
else:
    print("There are no statistically significant differences among the groups.")

print("F-statistic:", f_statistic)
print("P-value:", p_value)
# Out:
# There are no statistically significant differences among the groups.
# F-statistic: 0.00010378808294306144
# P-value: 0.9998962182004141

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Define the data as a 2x2 contingency table
observed = np.array([[42, 100 - 42], [8, 100 - 8]])

# Perform the chi-squared test for independence
chi2, p_value, _, _ = chi2_contingency(observed)

print("Chi-squared statistic:", chi2)
print("P-value:", p_value)
# Out:
# Chi-squared statistic: 29.04
# P-value: 7.089913521079198e-08

# %%
import scipy.stats as stats

# Define the contingency table
contingency_table = [[42, 100 - 42], [8, 100 - 8]]

# Perform Fisher's Exact Test
odds_ratio, p_value = stats.fisher_exact(contingency_table)

print("Odds Ratio:", odds_ratio)
print("P-value:", p_value)
# Out:
# Odds Ratio: 8.327586206896552
# P-value: 2.614280229026599e-08

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Define the data as a 3x5 contingency table
data = np.array([
    [0, 0, 21.4, 35.7, 42.8],
    [0, 0, 23.0, 46.1, 30.7],
    [0, 27.3, 18.9, 45.4, 9.0]
])

# Add a small constant to the data to avoid zero expected frequencies
small_const = 0.01
data_with_const = data + small_const

# Perform the chi-squared test for independence
chi2, p_value, _, _ = chi2_contingency(data_with_const)

print("Chi-squared statistic:", chi2)
print("P-value:", p_value)
# Out:
# Chi-squared statistic: 77.67938182731112
# P-value: 1.4314197070372824e-13

# %%
import scipy.stats as stats

# Define the contingency table for PGY-1 and PGY-2
contingency_table = [[42.8, 57.2], [30.8, 69.2]]

# Perform Fisher's Exact Test
odds_ratio, p_value = stats.fisher_exact(contingency_table)

print("Odds Ratio:", odds_ratio)
print("P-value:", p_value)
# Out:
# Odds Ratio: 1.694736842105263
# P-value: 0.1038353483234762

# %%
import scipy.stats as stats

# Define the contingency table for PGY-1 and PGY-3
contingency_table = [[42.8, 57.2], [8.9, 91.1]]

# Perform Fisher's Exact Test
odds_ratio, p_value = stats.fisher_exact(contingency_table)

print("Odds Ratio:", odds_ratio)
print("P-value:", p_value)
# Out:
# Odds Ratio: 8.381578947368421
# P-value: 2.482073018251321e-08

# %%
import scipy.stats as stats

# Define the contingency table for PGY-2 and PGY-3
contingency_table = [[30.8, 69.2], [8.9, 91.1]]

# Perform Fisher's Exact Test
odds_ratio, p_value = stats.fisher_exact(contingency_table)

print("Odds Ratio:", odds_ratio)
print("P-value:", p_value)
# Out:
# Odds Ratio: 4.945652173913044
# P-value: 0.00010766679245208154

# %%
import scipy.stats as stats

# Define the contingency table for PGY-1 and PGY-2
contingency_table = [[85.7, 14.3], [84.7, 15.3]]

# Perform Fisher's Exact Test
odds_ratio, p_value = stats.fisher_exact(contingency_table)

print("Odds Ratio:", odds_ratio)
print("P-value:", p_value)
# Out:
# Odds Ratio: 1.0841836734693877
# P-value: 1.0

# %%
import scipy.stats as stats

# Define the contingency table for PGY-1 and PGY-3
contingency_table = [[85.7, 14.3], [72.9, 27.1]]

# Perform Fisher's Exact Test
odds_ratio, p_value = stats.fisher_exact(contingency_table)

print("Odds Ratio:", odds_ratio)
print("P-value:", p_value)
# Out:
# Odds Ratio: 2.2767857142857144
# P-value: 0.034499571679751706

# %%
import scipy.stats as stats

# Define the contingency table for PGY-2 and PGY-3
contingency_table = [[84.7, 15.3], [72.9, 27.1]]

# Perform Fisher's Exact Test
odds_ratio, p_value = stats.fisher_exact(contingency_table)

print("Odds Ratio:", odds_ratio)
print("P-value:", p_value)
# Out:
# Odds Ratio: 2.1
# P-value: 0.055027473664134616

# %%
import scipy.stats as stats

# Define the contingency tables for each comparison
contingency_table_p1_p2 = [[50, 50], [46.2, 53.8]]
contingency_table_p1_p3 = [[50, 50], [45.1, 54.9]]
contingency_table_p2_p3 = [[46.2, 53.8], [45.1, 54.9]]

# Perform Fisher's Exact Test for each comparison
odds_ratio_p1_p2, p_value_p1_p2 = stats.fisher_exact(contingency_table_p1_p2)
odds_ratio_p1_p3, p_value_p1_p3 = stats.fisher_exact(contingency_table_p1_p3)
odds_ratio_p2_p3, p_value_p2_p3 = stats.fisher_exact(contingency_table_p2_p3)

print("PGY-1 vs. PGY-2:")
print("Odds Ratio:", odds_ratio_p1_p2)
print("P-value:", p_value_p1_p2)
print()

print("PGY-1 vs. PGY-3:")
print("Odds Ratio:", odds_ratio_p1_p3)
print("P-value:", p_value_p1_p3)
print()

print("PGY-2 vs. PGY-3:")
print("Odds Ratio:", odds_ratio_p2_p3)
print("P-value:", p_value_p2_p3)
# Out:
# PGY-1 vs. PGY-2:
# Odds Ratio: 1.1521739130434783
# P-value: 0.6712367035512364
#
# PGY-1 vs. PGY-3:
# Odds Ratio: 1.2
# P-value: 0.5712421394829708
#
# PGY-2 vs. PGY-3:
# Odds Ratio: 1.0415094339622641
# P-value: 1.0

# %%
import scipy.stats as stats

# Define the contingency tables for each comparison
contingency_table_p1_p2 = [[50, 50], [46.2, 53.8]]
contingency_table_p1_p3 = [[50, 50], [45.1, 54.9]]
contingency_table_p2_p3 = [[46.2, 53.8], [45.1, 54.9]]

# Perform Fisher's Exact Test for each comparison
odds_ratio_p1_p2, p_value_p1_p2 = stats.fisher_exact(contingency_table_p1_p2)
odds_ratio_p1_p3, p_value_p1_p3 = stats.fisher_exact(contingency_table_p1_p3)
odds_ratio_p2_p3, p_value_p2_p3 = stats.fisher_exact(contingency_table_p2_p3)

# Set the significance level
alpha = 0.05

# Determine and print the results
print("PGY-1 vs. PGY-2:")
print("Odds Ratio:", odds_ratio_p1_p2)
print("P-value:", p_value_p1_p2)
if p_value_p1_p2 < alpha:
    print("Result: Statistically significant")
else:
    print("Result: Not statistically significant")
print()

print("PGY-1 vs. PGY-3:")
print("Odds Ratio:", odds_ratio_p1_p3)
print("P-value:", p_value_p1_p3)
if p_value_p1_p3 < alpha:
    print("Result: Statistically significant")
else:
    print("Result: Not statistically significant")
print()

print("PGY-2 vs. PGY-3:")
print("Odds Ratio:", odds_ratio_p2_p3)
print("P-value:", p_value_p2_p3)
if p_value_p2_p3 < alpha:
    print("Result: Statistically significant")
else:
    print("Result: Not statistically significant")
# Out:
# PGY-1 vs. PGY-2:
# Odds Ratio: 1.1521739130434783
# P-value: 0.6712367035512364
# Result: Not statistically significant
#
# PGY-1 vs. PGY-3:
# Odds Ratio: 1.2
# P-value: 0.5712421394829708
# Result: Not statistically significant
#
# PGY-2 vs. PGY-3:
# Odds Ratio: 1.0415094339622641
# P-value: 1.0
# Result: Not statistically significant
